# %%
import numpy as np
from numpy import fft as fft

from matplotlib import pyplot as plt

# %%
stress = np.genfromtxt("log.shear.T1.5.rho0.85.txt", delimiter = ' ', skip_header = True)
stress
# Out:
# array([[ 0.00000000e+00,  2.92662054e-02,  6.49813142e-02,
#         -3.11933138e-02],
#        [ 2.00000000e-03,  2.67048599e-02,  6.78719643e-02,
#         -2.65758156e-02],
#        [ 4.00000000e-03,  2.38838086e-02,  7.12500783e-02,
#         -2.08668323e-02],
#        ...,
#        [ 2.49996000e+02,  2.07047371e-03, -3.70096503e-02,
#         -1.91048417e-01],
#        [ 2.49998000e+02,  3.19447940e-03, -3.74107455e-02,
#         -1.95135615e-01],
#        [ 2.50000000e+02,  3.89272686e-03, -3.81536422e-02,
#         -1.98051844e-01]])

# %%
time, pxy, pxz, pyz = stress[:,0], stress[:,1], stress[:,2], stress[:,3]

# %%
def acf(data, npts = None):
    """
    Computes time autocorrelation function of a real-valued array `data`.
    """
    
    n = len(data)
    if npts is None:
        npts = n
    npts = min(npts, n)
    dataf = fft.rfft(np.append(data, np.zeros(n)))
    acf = fft.irfft(np.conj(dataf) * dataf)[0:npts]
    for i in range(npts):
        acf[i] /= n - i
    
    return acf[0:npts]

# %%
plt.plot(time[0:1000], acf(pxy, 1000))

# %%
def integrate(ydata, xdata = None):
    """
    Computes running integral of `ydata` using `xdata` as abscissae.
    """
    
    n = len(ydata)
    if xdata is None:
        xdata = range(n)
    
    integ = np.zeros(n)
    for i in range(1,n):
        integ[i] = integ[i-1] + (ydata[i-1] + ydata[i]) / 2 * (xdata[i] - xdata[i-1])
    
    return integ

# %%
intxy, intxz, intyz = integrate(acf(pxy, 10000), time), integrate(acf(pxz, 10000), time), integrate(acf(pyz, 10000), time)

# %%
fig = plt.figure()
plotint = fig.add_subplot(111)
plotint.plot(time[0:10000], intxy, label="XY")
plotint.plot(time[0:10000], intxz, label="XZ")
plotint.plot(time[0:10000], intyz, label="YZ")
plotint.plot(time[0:10000], (intxy + intxz + intyz) / 3, label="Average")

plt.legend()

plt.show()

# %%
v = 15*15*15/0.85
v
# Out:
# 3970.5882352941176

# %%
0.0008*v/1.5
# Out:
# 2.1176470588235294
