# %%
import numpy as np
from numpy import fft as fft

import pylab as plt

# %%
stress = np.genfromtxt("log.shear.T1.5.rho0.67.txt", delimiter = ' ', skip_header = True)
stress
# Out:
# array([[ 0.00000000e+00,  1.08685522e-01,  3.48826128e-02,
#          2.31226033e-02],
#        [ 2.00000000e-03,  1.09832713e-01,  3.23394744e-02,
#          1.93079722e-02],
#        [ 4.00000000e-03,  1.10620878e-01,  3.00434811e-02,
#          1.51302714e-02],
#        ...,
#        [ 2.49996000e+02, -1.22001868e-01,  3.63966670e-02,
#         -7.53320809e-02],
#        [ 2.49998000e+02, -1.20192221e-01,  3.91149231e-02,
#         -7.12297254e-02],
#        [ 2.50000000e+02, -1.17537283e-01,  4.18017486e-02,
#         -6.66042615e-02]])

# %%
time, pxy, pxz, pyz = stress[:,0], stress[:,1], stress[:,2], stress[:,3]

# %%
def acf(data, npts = None):
    """
    Computes time autocorrelation function of a real-valued array `data`.
    """
    
    n = len(data)
    if npts is None:
        npts = n
    npts = min(npts, n)
    dataf = fft.rfft(np.append(data, np.zeros(n)))
    acf = fft.irfft(np.conj(dataf) * dataf)[0:npts]
    for i in range(npts):
        acf[i] /= n - i
    
    return acf[0:npts]

# %%
plt.plot(time[0:1000], acf(pxy, 1000))

# %%
def integrate(ydata, xdata = None):
    """
    Computes running integral of `ydata` using `xdata` as abscissae.
    """
    
    n = len(ydata)
    if xdata is None:
        xdata = range(n)
    
    integ = np.zeros(n)
    for i in range(1,n):
        integ[i] = integ[i-1] + (ydata[i-1] + ydata[i]) / 2 * (xdata[i] - xdata[i-1])
    
    return integ

# %%
intxy, intxz, intyz = integrate(acf(pxy, 1000), time), integrate(acf(pxz, 1000), time), integrate(acf(pyz, 1000), time)

# %%
fig = plt.figure()
plotint = fig.add_subplot(111)
plotint.plot(time[0:10000], intxy, label="XY")
plotint.plot(time[0:1000], intxz, label="XZ")
plotint.plot(time[0:1000], intyz, label="YZ")
plotint.plot(time[0:1000], (intxy + intxz + intyz) / 3, label="Average")

plt.legend()

plt.show()

# %%
time.shape
# Out:
# (125001,)

# %%
t = 5000
Gtime = time[0:t]

stress = np.genfromtxt("log.shear.T1.5.rho0.67.txt", delimiter = ' ', skip_header = True)
time, pxy, pxz, pyz = stress[:,0], stress[:,1], stress[:,2], stress[:,3]
intxy, intxz, intyz = integrate(acf(pxy, t), time), integrate(acf(pxz, t), time), integrate(acf(pyz, t), time)
T15r67=(intxy + intxz + intyz) / 3

stress = np.genfromtxt("log.shear.T1.5.rho0.85.txt", delimiter = ' ', skip_header = True)
time, pxy, pxz, pyz = stress[:,0], stress[:,1], stress[:,2], stress[:,3]
intxy, intxz, intyz = integrate(acf(pxy, t), time), integrate(acf(pxz, t), time), integrate(acf(pyz, t), time)
T15r85=(intxy + intxz + intyz) / 3

stress = np.genfromtxt("log.shear.T1.4.rho0.67.txt", delimiter = ' ', skip_header = True)
time, pxy, pxz, pyz = stress[:,0], stress[:,1], stress[:,2], stress[:,3]
intxy, intxz, intyz = integrate(acf(pxy, t), time), integrate(acf(pxz, t), time), integrate(acf(pyz, t), time)
T14r67=(intxy + intxz + intyz) / 3

stress = np.genfromtxt("log.shear.T1.5.rho0.64.txt", delimiter = ' ', skip_header = True)
time, pxy, pxz, pyz = stress[:,0], stress[:,1], stress[:,2], stress[:,3]
intxy, intxz, intyz = integrate(acf(pxy, t), time), integrate(acf(pxz, t), time), integrate(acf(pyz, t), time)
T15r64=(intxy + intxz + intyz) / 3

stress = np.genfromtxt("log.shear.T1.4.rho0.64.txt", delimiter = ' ', skip_header = True)
time, pxy, pxz, pyz = stress[:,0], stress[:,1], stress[:,2], stress[:,3]
intxy, intxz, intyz = integrate(acf(pxy, t), time), integrate(acf(pxz, t), time), integrate(acf(pyz, t), time)
T14r64=(intxy + intxz + intyz) / 3

stress = np.genfromtxt("log.shear.T1.5.rho0.61.txt", delimiter = ' ', skip_header = True)
time, pxy, pxz, pyz = stress[:,0], stress[:,1], stress[:,2], stress[:,3]
intxy, intxz, intyz = integrate(acf(pxy, t), time), integrate(acf(pxz, t), time), integrate(acf(pyz, t), time)
T15r61=(intxy + intxz + intyz) / 3

stress = np.genfromtxt("log.shear.T1.4.rho0.61.txt", delimiter = ' ', skip_header = True)
time, pxy, pxz, pyz = stress[:,0], stress[:,1], stress[:,2], stress[:,3]
intxy, intxz, intyz = integrate(acf(pxy, t), time), integrate(acf(pxz, t), time), integrate(acf(pyz, t), time)
T14r61=(intxy + intxz + intyz) / 3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 4>()
#       1 t = 5000
#       2 Gtime = time[0:t]
# ----> 4 stress = np.genfromtxt("log.vacf.T1.5.rho0.67.txt", delimiter = ' ', skip_header = True)
#       5 time, pxy, pxz, pyz = stress[:,0], stress[:,1], stress[:,2], stress[:,3]
#       6 intxy, intxz, intyz = integrate(acf(pxy, t), time), integrate(acf(pxz, t), time), integrate(acf(pyz, t), time)
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/npyio.py:2145, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, like)
#    2143 # Raise an exception ?
#    2144 if invalid_raise:
# -> 2145     raise ValueError(errmsg)
# ...

# %%
fig = plt.figure(figsize=(15,12))
plt.plot(Gtime, T15r67, label='T=1.5; '+r"$\rho=0.67$", lw=3)
plt.plot(Gtime, T15r64, label='T=1.5; '+r"$\rho=0.64$", lw=3)
plt.plot(Gtime, T15r61, label='T=1.5; '+r"$\rho=0.61$", lw=3)
plt.plot(Gtime, T14r67, label='T=1.4; '+r"$\rho=0.67$", lw=3)
plt.plot(Gtime, T14r64, label='T=1.4; '+r"$\rho=0.64$", lw=3)
plt.plot(Gtime, T14r61, label='T=1.4; '+r"$\rho=0.61$", lw=3)
plt.legend(fontsize=20)
plt.grid()
plt.xlabel(r"$\tau$", fontsize=20)
plt.ylabel("D", fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
